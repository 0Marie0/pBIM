# %% [markdown]
# # Main

# %%
using Pkg
Pkg.add("Revise")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `~/.julia/environments/v1.12/Project.toml`
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
#using Revise
#includet("hamiltonian_path.jl")

# %%
using Revise
includet("visualization.jl")
# Out:
# ERROR: UndefVarError: `HamiltonianPath` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
# Stacktrace:
#  [1] top-level scope
#    @ ~/Documents/master/m1/s2/projet/code/visualization.jl:2
# in expression starting at /Users/marie.gabilly/Documents/master/m1/s2/projet/code/visualization.jl:2

# %%
using Revise
includet("metropolis.jl")
# Out:
# Starting backtracking
# Calculation of all conformations
# Step 1: Exploration from the corner (node 1)
# Step 2: Exploration from the center of the face (node 5)
# algo (β=100) 100%|███████████████████████████████████████| Time: 0:00:07

# %%
using Revise
includet("benchmark.jl")
# Out:
# Starting backtracking
# Calculation of all conformations
# Step 1: Exploration from the corner (node 1)
# Step 2: Exploration from the center of the face (node 5)
# algo (β=100) 100%|███████████████████████████████████████| Time: 0:00:06

# %% [markdown]
# ## Hamiltonian paths

# %%
using .HamiltonianPath: PATHS, paths_to_file 

println("We find $(length(PATHS)) unique paths.")
println(first(PATHS))
# Out:
# UndefVarError: `HamiltonianPath` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] eval(m::Module, e::Any)
#
#    @ Core ./boot.jl:489
#
#  [2] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#    @ Base ./loading.jl:2870
#
#  [3] (::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String})()
#
#    @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
#
#  [4] withpath(f::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#    @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/repl.jl:303
#
#  [5] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#    @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [6] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#    @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/JSONRPC/src/typed.jl:0
#
#  [7] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#20#21"{String})
#
#    @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
#
#  [8] top-level scope
#
#    @ ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/notebook/notebook.jl:28

# %%
using .Visualization: contact_map, plot_cube_ctc_map, x, y, z, lx, ly, lz, plot_cube_path

println("Contact map for the first path:")
liste_contact = contact_map(PATHS[75005])
display(plot_cube_ctc_map(x, y, z, lx, ly, lz, liste_contact))

println("Path visualization for the 75005:")
display(plot_cube_path(x, y, z, lx, ly, lz, PATHS[75005]))
# Out:
# Contact map for the first path:
# WARNING: Imported binding Visualization.contact_map was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.plot_cube_ctc_map was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.x was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.y was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.z was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.lx was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.ly was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.lz was undeclared at import time during import to Main.
# WARNING: Imported binding Visualization.plot_cube_path was undeclared at import time during import to Main.
# UndefVarError: `contact_map` not defined in `Main`
#
# Suggestion: this global was defined as `Main.Visualization.contact_map` but not assigned a value.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/master/m1/s2/projet/code/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W6sZmlsZQ==.jl:4

# %% [markdown]
# ## Metropolis general results

# %%
using .Metropolis: algo, all_ctc_maps, generate_seq
using Plots

seq = generate_seq()
target_number = 75005


final_seq, p_struct_time_t,_=algo(seq, target_number, all_ctc_maps, 10000, 100)
t=1:length(p_struct_time_t)
plot(t, p_struct_time_t, xlabel="Time", ylabel="Probability", title="Evolution of the probability of the sequence over time")
# Out:
# algo (β=100)  74%|█████████████████████████████          |  ETA: 0:00:19
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] setindex!(h::Dict{Int64, Float64}, v0::Float64, key::Int64)
#
#     @ Base ./dict.jl:354
#
#   [2] metropolis(mut::Tuple{Int64, Int64}, seq::Vector{Int64}, target_number::Int64, weights::Vector{Float64}, pos_contacts::Vector{Vector{Tuple{Int64, Int64}}}, ttl_energy::Float64, log_proba_target::Float64, affected::Dict{Int64, Float64}, beta::Int64)
#
#     @ Main.Metropolis ~/Documents/master/m1/s2/projet/code/metropolis.jl:148
#
#   [3] macro expansion
#
#     @ ~/Documents/master/m1/s2/projet/code/metropolis.jl:222 [inlined]
#
#   [4] macro expansion
#
#     @ ~/.julia/packages/ProgressMeter/N660J/src/ProgressMeter.jl:1026 [inlined]
#
#   [5] algo(seq::Vector{Int64}, target_number::Int64, all_ctc_maps::Vector{Any}, epochs::Int64, beta::Int64, threshold::Int64, step::Int64, show_progress::Bool)
#
#     @ Main.Metropolis ~/Documents/master/m1/s2/projet/code/metropolis.jl:212
#
#   [6] algo(seq::Vector{Int64}, target_number::Int64, all_ctc_maps::Vector{Any}, epochs::Int64, beta::Int64)
#
#     @ Main.Metropolis ~/Documents/master/m1/s2/projet/code/metropolis.jl:200
#
#   [7] eval(m::Module, e::Any)
#
#     @ Core ./boot.jl:489
#
#   [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:2870
#
#   [9] (::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
#
#  [10] withpath(f::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/repl.jl:303
#
#  [11] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [12] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/JSONRPC/src/typed.jl:0
#
#  [13] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#20#21"{String})
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
#
#  [14] top-level scope
#
#     @ ~/.vscode/extensions/julialang.language-julia-1.189.2/scripts/notebook/notebook.jl:28

# %%
# benchmarking ß
using .Benchmark: benchmark_beta
benchmark_beta()
# Out:
# Testing beta = 10
# algo (β=10)   1%|▌                                       |  ETA: 0:00:31

# %% [markdown]
# ## Further observations

# %% [markdown]
# ### Chain evolution

# %% [markdown]
# ### Probability comparison
