# %% [markdown]
# # Test avec Julia

# %%
print("OUEOUEOUE")
# Out:
# OUEOUEOUE

# %%
a = 29
a + 1
# Out:
# 30

# %%
function val_abs(a, b)
    if a > b
        return a - b
    else
        return b - a
    end
end


val_abs(-3, a)
# Out:
# 32
